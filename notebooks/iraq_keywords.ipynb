# %%
import json

IRAQ_KEYWORDS = {
    "geographic": {
        "weight": 10,
        "terms": [
            "iraq", "عراق" ,"العراق",
            "iraqi", "عراقي" ,"عراقيه",
            "mesopotamia", "mesopotamie",
            "fertile crescent",
            "بلاد الرافدين", "بلاد ما بين النهرين", "حضارة الرافدين",
            "sumerian", "sumer", "سومري", "سومر",
            "akkadian", "akkad", "أكدي", "أكدية",
            "nineveh", "niniveh", "ninua", "نينوى" ,"نينوا"
            "nimrud", "nimroud", "نمرود",
            "kalhu", "كالخو",
            "babylon", "babylonia", "babylonian", "babil", "babel", "babilim", "بابل" ,"بابلية" ,"بابلي",
            "uruk", "warka", "الوركاء" ,"وركاء" ,"أوروك",
            "nippur", "afak", "نيبور" ,"عفك",
            "assur", "ashur", "assyria", "assyrian", "آشور" ,"آشورية" ,"آشوري",
            "mosul", "الموصل",
            "erbil", "arbil", "أربيل",
            "samarra", "samara", "سامراء",
            "kirkuk", "كركوك",
            "hatra", "الحضر",
            "ctesiphon", "tesiphon", "قطسيفون",
            "seleucia", "سلوقية",
            "lagash", "لكش", "لاجاش",
            "larsa", "لارسا",
            "baghdad", "بغداد" ,"البغداد",
            "kish", "كيش",
            "isin", "إيسن",
            "adab", "أداب",
            "shuruppak", "شوروباك",
            "sippar", "سيبار",
            "diyala", "ديالى",
            "tell asmar", "تل أسمر",
            "nuzi", "nuzu", "نوزي",
            "eshnunna", "إشنونا",
            "khorsabad", "دور شروكين",
            "tello", "telloh", "تللو", "تلو",
            "sinjar", "سنجار",
            "shanidar", "shanidar cave", "شانيدار", "كهف شانيدر",
            "anbar", "الأنبار",
            "jemdet nasr", "جمدة نصر",
            "basra", "basrah", "البصرة" ,"بصرة",
            "najaf", "النجف",
            "karbala", "كربلاء",
            "nasiriyah", "الناصرية",
            "wasit", "واسط",
            "me-turan", "tell haddad", "tell al-sib", "مي توران" ,"تل حداد" ,"تل السيب",
            "tell yelkhi", "awal", "تل يلخي" ,"أوال",
            "tutub", "khafajah", "توتوب" ,"خفاجية",
            "der", "tell aqar", "دير" ,"تل عقار",
            "tell abu habbah", "تل أبو حبة",
            "sippar-amnanum", "tell ed-der", "سيبار أمنانوم" ,"تل الدير",
            "tell uqair", "urum", "تل عقير" ,"أوروم",
            "kutha", "tell ibrahim", "كوثى" ,"تل إبراهيم",
            "tell uheimir", "ingharra", "تل الأحيمر" ,"إنغرة",
            "borsippa", "birs nimrud", "بورسيبا" ,"برس نمرود",
            "malgium", "tulul al-faj", "tell yassir", "مالگيوم" ,"تلول الفاج" ,"تل ياسر",
            "mashkan-shapir", "tell abu duwari", "مشكن شابير" ,"تل أبو دواري",
            "dilbat", "tell ed-duleim", "دلبات" ,"تل الدليم",
            "marad", "tell wannat es-sadum", "مراد" ,"تل ونة السعدون",
            "tell bismaya", "تل بسماية",
            "ishan al-bahriyat", "إيشان البحرية",
            "kisurra", "tell abu hatab", "كيسورا" ,"تل أبو حطب",
            "tell fara", "تل فارة",
            "karkar", "tell gidr", "كركر" ,"تل جدر",
            "bad-tibira", "tell al-madineh", "باد تيبيرا" ,"تل المدينة",
            "zabalam", "tell ibzeikh", "زابالام" ,"تل إبزيخ",
            "umma", "umm al-aqarib", "tell jokha", "أوما" ,"أم العقارب" ,"تل جوخة",
            "girsu", "جرسو",
            "tell al-hiba", "تل الهيبة",
            "tell zurghul", "nigin", "تل الزرغل" ,"نيجين",
            "tell as-senkereh", "تل السنكرة",
            "pasime", "pashime", "tell abu sheeja", "باشيمي" ,"تل أبو شيجة",
            "tell khaiber", "تل خيبر",
            "tell al-wilayah", "irisagrig", "تل الولاية" ,"إريساجريگ",
            "tulul al-baqarat", "kesh", "تلول البقرات" ,"كيش",
            "tell al-muqayyar", "أور" ,"تل المقير",
            "tell al-lahm", "dur-iakin", "kisik", "kuara", "تل اللحم" ,"دور ياكين" ,"كيسيك" ,"كوارا",
            "eridu", "tell abu shahrain", "إريدو" ,"تل أبو شهرين",
            "tell al-ubaid", "nutur", "تل العبيد" ,"نوتور",
            "akshak", "أكشاك",
            "urkesh", "urkish", "tell mozan", "أوركيش" ,"تل موزان",
            "mardaman", "bassetki", "مردمان" ,"باستكي",
            "kahat", "tell barri", "كاهات" ,"تل بري",
            "hamazi", "همازي",
            "yarim tepe", "يارم تبه",
            "telul eth-thalathat", "تلول الثلاثات",
            "tepe gawra", "تبه كورا",
            "tell arpachiyah", "tepe reshwa", "تل الأربجية" ,"تبه رشوة",
            "tell maghzaliyah", "تل مغزلية",
            "shibaniba", "tell billa", "شيبانيبا" ,"تل بلة",
            "tarbisu", "sherif khan", "تربصو" ,"شريف خان",
            "qatara", "karana", "tell al-rimah", "قطارا" ,"كارانا" ,"تل الرماح",
            "tell hamoukar", "تل حموكار",
            "tell al-hawa", "razama", "تل الهوى" ,"رازاما",
            "dur sharrukin", "khorsabad", "دور شروكين" ,"خورسباد",
            "tell shemshara", "shusharra", "تل شمشارة" ,"شوشارا",
            "bestansur", "بستنسور",
            "tell bazmusian", "تل بازموسيان",
            "erbil", "urbilim", "arba-ilu", "أربيل" ,"أوربيليم" ,"أربا إيلو",
            "kurd qaburstan", "qabra", "كرد قبورستان" ,"قبرا",
            "qasr shemamok", "kilizu", "kilizi", "kakzu", "قصر شمامك" ,"كليزي",
            "qalat jarmo", "قلعة جرمو",
            "tell taya", "تل الطاية",
            "tell hassuna", "تل حسونة",
            "balawat", "imgur-enlil", "بلاوات" ,"إمگور إنليل",
            "arrapha", "عرفة",
            "kar-tukulti-ninurta", "كار توكلتي نينورتا",
            "ekallatum", "إيكالاتوم",
            "nuzi", "yorghan tepe", "gasur", "نوزي" ,"يورغان تبه" ,"گاسور",
            "tell al-fakhar", "kurruhanni", "تل الفخار" ,"كوروهاني",
            "tell taban", "tabetu", "tabatum", "تل تابان" ,"تابيتو" ,"تاباتوم",
            "tell es-sawwan", "تل الصوان",
            "nerebtum", "kiti", "tell ishchali", "نيريبتوم" ,"كيتي" ,"تل إشجالي",
            "tell agrab", "تل أگراب",
            "dur-kurigalzu", "aqar quf", "دور كوريكالزو" ,"عقرقوف",
            "shaduppum", "tell harmal", "شدوبوم" ,"تل حرمل",
            "tell al-dhibai", "تل الذيباعي",
            "tell muhammad", "تل محمد",
            "ctesiphon", "taq kisra", "المدائن" ,"طاق كسرى",
            "idu", "إيدو",
            "rabana-merquly", "natounia", "ربانة مركولي" ,"ناتونيا"
        ]
    },
    
    "cultural_historical": {
        "weight": 6,
        "terms": [
            "chaldean", "كلدان" ,"كلداني",
            "amorite", "amorrite", "ammurite", "ammorite", "أمور" ,"أموري",
            "cassite", "kassite", "كاش" ,"كاشي",
            "hurrian", "حور" ,"حوري",
            "mitanni", "ميتان" ,"ميتاني",
            "ubaid", "obeid", "عبيد",
            "early dynastic", "فجر السلالات",
            "third dynasty of ur", "ur iii", "السلالة الثالثة من أور",
            "kufic", "kufi", "كوفي",
            "halaf", "حلف" ,"حلفي",
            "parthian", "فرث" ,"فرثي",
            "sasanian", "sasanid", "ساسان" ,"ساساني",
            "abbasid", "عباس" ,"عباسي",
            "umayyad", "أمو" ,"أموي",
            "islamic", "إسلام" ,"إسلامي",
            "arab", "arabic", "عربي",
            "ottoman", "عثمان" ,"عثماني",
            "subarian", "سوبار" ,"سوباري",
            "gutian", "غوت" ,"غوتي",
            "elamite", "عيلام" ,"عيلامي",
            "lulubi", "لولوب" ,"لولوبي",
            "aramaean", "aramaic", "آرام" ,"آرامي",
            "mandaean", "mandaic", "مندا" ,"مندائي",
            "nabataean", "نبط" ,"نبطي",
            "seleucid", "سلوق" ,"سلوقي",
            "hellenistic", "هلنستي",
            "achaemenid", "أخميني",
            "late antique", "العصر المتأخر القديم",
            "medieval", "عصور وسطى",
            "buyid", "بويهي",
            "seljuk", "سلجوق" , "سلجوقي",
            "atabeg", "أتابك" ,"أتابكي",
            "mongol", "مغول" ,"مغولي",
            "ilkhanid", "إيلخان" ,"إيلخاني",
            "jalayirid", "جلائر" ,"جلائري",
            "timurid", "تيمور" ,"تيموري",
            "safavid", "صفوي",
            "mamluk", "مملوك" ,"مملوكي",
            "nestorian", "نسطور" ,"نسطوري",
            "east syriac", "سرياني شرقي",
            "yazidi", "يزيدي",
            "faisal", "feisal", "فيصل",       
            "ghazi", "غازي",
            "hashemite", "هاشمي" ,"الهاشمية",
            "nebuchadnezzar", "نابوخذنصر" ,"لنابوخذنصر",
            "sargon", "sargonic", "sargonid", "سارجون" ,"سارجوني" ,"سارجونية" ,"سارجونيد"
        ]
    },
    
    "object_types": {
        "weight": 2,
        "terms": [
            "cuneiform", "cuniform", "cunieform", "مسماري", "كتابة مسمارية",
            "tablet fragment", "قطعة لوح طيني",
            "fragment of tablet", "قطعة لوح",        
            "inscribed tablet", "لوح منقوش",
            "wedge script", "كتابة إسفينية",        
            "administrative tablet", "لوح إداري",
            "legal tablet", "لوح قانوني",
            "lexical tablet", "لوح لغوي",
            "school tablet", "لوح مدرسي",
            "cylinder seal", "ختم أسطواني",
            "stamp seal", "ختم حجري",
            "hematite seal", "ختم هيماتيت",
            "chalcedony seal", "ختم عقيق",
            "lapis seal", "ختم لاجورد",
            "scaraboid seal", "ختم جُعَلّي",
            "glyptic", "فن الأختام",
            "inscribed seal", "ختم منقوش",
            "seal impression", "بصمة ختم",        
            "bullae", "bulla", "أختام طينية" ,"ختم طيني",
            "clay cone", "مخروط طيني",
            "clay envelope", "ظرف طيني",
            "clay tablet", "لوح طيني", "رقيم طيني",        
            "inscribed brick", "طابوقة منقوشة",
            "brick inscription", "نقش على طوب",
            "royal inscription", "نقش ملكي",
            "kudurru", "مسلة حدود",
            "terracotta", "فخار",
            "vessel", "إناء",
            "boundary stone", "حجر حدود",
            "foundation cone", "مخروط تأسيسي",
            "foundation peg", "وتد تأسيسي",
            "foundation nail", "مسمار تأسيسي",
            "stamped brick", "طوب مختوم",
            "mud brick", "طوب لبن",
            "glazed brick", "طوب مزجج",
            "architectural fragment", "قطعة معمارية",
            "architectural relief", "نقش معماري",
            "wall relief", "نقش جداري",
            "column capital", "تيجان أعمدة",
            "capital fragment", "قطعة تاج عمود",
            "column base", "قاعدة عمود",
            "frieze fragment", "قطعة إفريز",
            "cornice fragment", "قطعة كورنيش",
            "stele", "stela", "مسلة",
            "grave marker", "علامة قبر",
            "statue", "تمثال",
            "head fragment", "قطعة رأس",
            "stone head", "رأس حجري",
            "torso fragment", "قطعة جذع",
            "mushussu", "مُشخوشو",
            "votive tablet", "لوح نذري",
            "incantation bowl", "وعاء تعاويذ",
            "magic bowl", "وعاء سحري",
            "mandaic bowl", "وعاء مندائي",
            "figurine", "تمثال صغير",
            "idol", "صنم" ,"تماثيل عيون",
            "orthostat", "حجر قائم منقوش",
            "relief fragment", "قطعة نقش بارز",
            "palace relief", "نقش قصر",
            "lamassu", "لاماسو",
            "winged bull", "ثور مجنح",
            "winged genie", "جني مجنح",
            "oil lamp", "مصباح زيتي",
            "lamp fragment", "قطعة مصباح",
            "ceramic lamp", "مصباح خزفي",
            "pottery", "فخار",
            "earthenware", "خزف فخاري",
            "stonepaste", "عجينة حجرية",
            "faience", "خزف فايانس",
            "fritware", "خزف فريت",
            "amulet", "تميمة",
            "talisman", "حجاب" ,"تميمة",
            "ritual object", "قطعة طقسية",
            "cult object", "قطعة عبادة",
            "votive object", "قطعة نذرية",
            "dagger", "خنجر",
            "sword", "سيف",
            "axe head", "رأس فأس",
            "spearhead", "نقطة رمح",
            "arrowhead", "رأس سهم",
            "mace head", "رأس هراوة",
            "bead", "خرزة",
            "necklace", "عقد",
            "pendant", "قلادة",
            "gold", "ذهب",
            "ring", "خاتم",
            "bracelet", "سوار",
            "earring", "قرط" ,"حلق",
            "mirror", "مرآة",
            "comb", "مشط",
            "pin", "دبوس",
            "ivory", "عاج",
            "coin", "عملة",
            "banknote", "الأوراق النقدية",
            "dirham", "درهم",
            "dinar", "دينار",
            "fals", "fils", "فلس",
            "astrolabe", "إسطرلاب", "الإسطرلاب",
            "manuscript", "مخطوطة",
            "quran", "koran", "مصحف" ,"قرآن",
            "calligraphy", "خط عربي",
            "waqf", "وقف",
            "leather binding", "تجليد جلدي",
            "tile fragment", "قطعة بلاط",
            "textile fragment", "قطعة نسيج",
            "woven fragment", "نسيج منسوج",
            "embroidered textile", "نسيج مطرز",
            "carpet fragment", "قطعة سجادة",
            "kilim", "كيليم",
            "quartz", "haematite", "hematite", "goethite", "magnetite", "calcite", "aragonite", "gypsum",
            "كوارتز" ,"هيماتيت" ,"غوثيت" ,"ماغنتيت" ,"كالسيت" ,"أراغونيت" ,"جبس",
            "dolomite", "serpentine", "soapstone", "chlorite", "diorite", "felsite", "granite", "greenstone",
            "دولوميت" ,"سربنتين" ,"حجر صابوني" ,"كلوريت" ,"ديوريت" ,"فيلسيت" ,"غرانيت" ,"حجر أخضر",
            "steatite", "agate", "alabaster", "carnelian", "chalcedony", "jasper", "limestone",
            "ستياتيت" ,"الكالسيدوني" ,"عقيق" ,"مرمر" ,"ألباستر" ,"عقيق أحمر" ,"كارنيليان" ,"خال عقيق أبيض" ,"كالسيدوني" ,"يشب" ,"حجر جيري",
            "bitumen", "stone", "socket", "disc", "wall slab", "prism", "barrel", "envelope",
            "بيتومين" ,"حجر" ,"مقبس" ,"قرص" ,"لوح جداري" ,"موشور" ,"برميل" ,"غلاف"
        ]
    },
    
    "iconography_mythology": {
        "weight": 2,
        "terms": [
            "gilgamesh", "جلجامش",
            "ishtar", "عشتار",
            "inanna", "إنانا",
            "shamash", "شمش",
            "marduk", "مردوخ",
            "enki", "إنكي",
            "nabu", "نابو",
            "ashur", "آشور",
            "apkallu", "أبكالو",
            "winged deity", "إله مجنح",
            "tree of life", "شجرة الحياة",
            "lion hunt relief", "مشهد صيد الأسود",
            "banquet scene", "مشهد وليمة",
            "rosette motif", "نقش وردة",
            "anu", "آنو", "أنو",
            "antu", "أنتو",
            "enlil", "إنليل",
            "ninlil", "نينليل",
            "ninurta", "نينورتا",
            "ningirsu", "نينجيرسو", "ننجرسو",
            "ereshkigal", "إريشكيجال", "إريشكيغال",
            "dumuzi", "دموزي",
            "tammuz", "تموز",
            "nanna", "نانا",
            "adad", "أداد",
            "hadad", "حدد", "هاداد",
            "nergal", "نرغال",
            "nisaba", "نيسابا",
            "geshtinanna", "جيشتينانا", "جشتينانا",
            "tiamat", "تيامات",
            "kingu", "كنغو", "كينغو",
            "lahmu", "لاهمو",
            "lahamu", "لاهامو",
            "uttu", "أوتو",
            "utu", "أوتو",
            "ashnan", "أشنان",
            "gula", "غولا",
            "belit", "بليت",
            "bel marduk", "بيل مردوخ" ,"بل مردوخ",
            "dagan", "داغان",
            "erra", "ايرا",
            "igigi", "إيجيجي",
            "sebetti", "سيبيتي",
            "suen", "سوين",
            "ninsumun", "ninsun", "نينسون" ,"نينسومون",
            "nanshe", "نانش",
            "temple", "معبد"
        ]
    },
    
    "dealer_language": {
        "weight": 1,
        "terms": [
            "near eastern", "الشرق الأدنى",
            "western asiatic", "آسيوي غربي",
            "biblical lands", "أرض الكتاب المقدس",
            "oriental", "الشرق القديم",
            "ancient", "عتيقة" ,"عتيق",
            "old", "قديم", "قديمة",
            "historic", "تاريخي",
            "prehistoric", "ما قبل التاريخ",
            "antiquity", "العصور القديمة",
            "artifact", "artefact", "قطعة أثرية",
            "museum", "متحف",
            "collector item", "قطعة لهواة الجمع",
            "collection item", "قطعة من مجموعة",
            "private collection", "مجموعة خاصة"
        ]
    },
}

NEGATIVES = [
    "replica", "نسخة مقلدة",
    "reproduction", "إعادة إنتاج",
    "inspired by", "مستوحى من",
    "modern copy", "نسخة حديثة",
    "imitation", "تقليد",
    "fake", "مزيف",
    "cast copy", "نسخة مصبوبة",
    "plaster cast", "قالب جبس",
    "resin cast", "راتنج مصبوب",
    "recast", "إعادة صب",
    "newly made", "صنع حديثاً",
    "vintage style", "نمط عتيق",
    "home decor", "ديكور منزلي",
    "wall decor", "ديكور جداري",
    "interior decor", "ديكور داخلي",
    "decorative piece", "قطعة ديكور",
    "souvenir", "تذكار",
    "in the style of", "على طراز",
    "inspired style", "أسلوب مستوحى",
    "modern interpretation", "تفسير حديث",
    "tribute piece", "قطعة تكريمية",
    "homage", "إشادة فنية",
    "fantasy", "خيالي",
    "3d printed", "طباعة ثلاثية الأبعاد",
    "laser cut", "قطع بالليزر",
    "machine made", "صنع آلي",
    "factory made", "صناعة مصنع",
    "mass produced", "إنتاج ضخم",
    "resin", "راتنج",
    "plastic", "بلاستيك",
    "fiberglass", "ألياف زجاجية",
    "printed model", "نموذج مطبوع",
    "3d model", "نموذج ثلاثي الأبعاد",
    "digital sculpt", "نحت رقمي",
    "laser engraved", "نقش بالليزر",
    "modern ceramic", "خزف حديث",
    "new casting", "صب حديث",
    "silicone mold", "قالب سيليكون",
    "modern era", "العصر الحديث",
    "contemporary", "معاصر",
    "prop", "إكسسوار تصوير"
    ]

with open('keywords.json', 'w', encoding='utf-8') as kf:
    json.dump(IRAQ_KEYWORDS, kf, indent=4)

with open('negative_keywords.json', 'w', encoding='utf-8') as nk:
    json.dump(NEGATIVES, nk, indent=4)
